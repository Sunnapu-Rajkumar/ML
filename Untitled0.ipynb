# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunnapu-Rajkumar/ML/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
cd
# Out:
# /root

# %%
pwd
# Out:
# '/root'

# %%
data_path = "/content/IMDB Dataset.csv"

# %%
df = pd.read_csv(data_path)

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.size
# Out:
# 100000

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df = df.head(100)

# %%
df
# Out:
#                                                review sentiment
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Basically there's a family where a little boy ...  negative
# 4   Petter Mattei's "Love in the Time of Money" is...  positive
# ..                                                ...       ...
# 95  Daniel Day-Lewis is the most versatile actor a...  positive
# 96  My guess would be this was originally going to...  negative
# 97  Well, I like to watch bad horror B-Movies, cau...  negative
# 98  This IS the worst movie I have ever seen, as w...  negative
# 99  I have been a Mario fan for as long as I can r...  positive
#
# [100 rows x 2 columns]

# %%
import re

def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
df.describe()
# Out:
#                                                    review sentiment
# count                                                 100       100
# unique                                                100         2
# top     One of the other reviewers has mentioned that ...  negative
# freq                                                    1        58

# %%
df['review'] = df['review'].str.lower()
# Out:
# <ipython-input-27-92c61e6b1a16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].str.lower()

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %%
df.describe()
# Out:
#                                                    review sentiment
# count                                                 100       100
# unique                                                100         2
# top     one of the other reviewers has mentioned that ...  negative
# freq                                                    1        58

# %%
def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return re.sub(clean,'', text)

# %%
df['review'] = df['review'].apply(lambda x: remove_html_tags(x))
# Out:
# <ipython-input-34-bb4f498d4dd6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].apply(lambda x: remove_html_tags(x))

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. the filming tec...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive
